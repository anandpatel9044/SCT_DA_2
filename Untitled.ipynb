# %%
import pandas as pd

# %%
df= pd.read_csv("Global Superstore.csv")

# %%
df.head() #for first rows dispaly
# Out:
#           Category         City        Country Customer ID     Customer Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  ji_lu-shu Order Date        Order ID  ... Sales   Segment  \
# 0       0.0     US          1    00:00.0  CA-2011-130813  ...    19  Consumer
# 1       0.0     US          1    00:00.0  CA-2011-148614  ...    19  Consumer
# 2       0.0     US          1    00:00.0  CA-2011-118962  ...    21  Consumer
# 3       0.0     US          1    00:00.0  CA-2011-118962  ...   111  Consumer
# 4       0.0     US          1    00:00.0  CA-2011-146969  ...     6  Consumer
#
# ...

# %%
df.info() # check information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer ID     51290 non-null  object
#  4   Customer Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   ji_lu-shu       51290 non-null  int64
#  8   Order Date      51290 non-null  object
#  9   Order ID        51290 non-null  object
#  10  Order Priority  51290 non-null  object
#  11  Product ID      51290 non-null  object
#  12  Product Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row ID          51290 non-null  int64
# ...

# %%
df.isnull().sum() # check null values
# Out:
# Category          0
# City              0
# Country           0
# Customer ID       0
# Customer Name     0
# Discount          0
# Market            0
# ji_lu-shu         0
# Order Date        0
# Order ID          0
# Order Priority    0
# Product ID        0
# Product Name      0
# Profit            0
# Quantity          0
# Region            0
# Row ID            0
# Sales             0
# Segment           0
# Ship Date         0
# Ship Mode         0
# Shipping Cost     0
# State             0
# Sub-Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df = df.dropna() # remove missing values

# %%
df.duplicated().sum() #duplicate rows
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates() #remove duplicate

# %%
df.dtypes #check datatypes
# Out:
# Category           object
# City               object
# Country            object
# Customer ID        object
# Customer Name      object
# Discount          float64
# Market             object
# ji_lu-shu           int64
# Order Date         object
# Order ID           object
# Order Priority     object
# Product ID         object
# Product Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row ID              int64
# Sales               int64
# Segment            object
# Ship Date          object
# Ship Mode          object
# Shipping Cost     float64
# State              object
# Sub-Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df.dtypes
# Out:
# Category                  object
# City                      object
# Country                   object
# Customer ID               object
# Customer Name             object
# Discount                 float64
# Market                    object
# ji_lu-shu                  int64
# Order Date        datetime64[ns]
# Order ID                  object
# Order Priority            object
# Product ID                object
# Product Name              object
# Profit                   float64
# Quantity                   int64
# Region                    object
# Row ID                     int64
# Sales                      int64
# Segment                   object
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Shipping Cost            float64
# State                     object
# Sub-Category              object
# Year                       int64
# Market2                   object
# weeknum                    int64
# dtype: object

# %%
df.head()
# Out:
#           Category         City        Country Customer ID     Customer Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  ji_lu-shu Order Date        Order ID  ... Sales   Segment  \
# 0       0.0     US          1 2026-06-30  CA-2011-130813  ...    19  Consumer
# 1       0.0     US          1 2026-06-30  CA-2011-148614  ...    19  Consumer
# 2       0.0     US          1 2026-06-30  CA-2011-118962  ...    21  Consumer
# 3       0.0     US          1 2026-06-30  CA-2011-118962  ...   111  Consumer
# 4       0.0     US          1 2026-06-30  CA-2011-146969  ...     6  Consumer
#
# ...

# %%
df.to_csv("Cleaned_Global_Superstore.csv", index=False) #cleaned data set

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer ID       0
# Customer Name     0
# Discount          0
# Market            0
# ji_lu-shu         0
# Order Date        0
# Order ID          0
# Order Priority    0
# Product ID        0
# Product Name      0
# Profit            0
# Quantity          0
# Region            0
# Row ID            0
# Sales             0
# Segment           0
# Ship Date         0
# Ship Mode         0
# Shipping Cost     0
# State             0
# Sub-Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64
